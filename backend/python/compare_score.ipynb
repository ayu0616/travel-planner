# %%
from test import get_scores
import pandas as pd
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
scores_list = []
names = [
    "sa",
    "climb_mt",
    # "beam",
    # "define_score",
]
for name in names:
    path = os.path.join("../dist/", name)
    scores_list.append(get_scores(path))

# %%
li = np.array(scores_list)
li = li.T
df = pd.DataFrame(li, columns=names)

# %%
df
# Out:
#           sa  climb_mt
# 0    42.0143   41.0063
# 1    37.0023   37.0063
# 2    42.0294   41.0227
# 3    40.0053   39.0061
# 4    35.0320   35.0662
# ..       ...       ...
# 495  38.0135   36.0021
# 496  34.0183   34.0160
# 497  32.0194   32.0090
# 498  46.0065   45.0086
# 499  39.0021   39.0341
#
# [500 rows x 2 columns]

# %%
# 折れ線グラフを描画
df.plot()
plt.xlabel("id")
plt.ylabel("score")
plt.show()

# %%
# ヒストグラムを描画
df.plot.kde()
plt.xlabel("Score")
plt.show()

# %%
df.plot.box()
plt.ylabel("Score")
plt.show()

# %%
df.describe()
# Out:
#                sa    climb_mt
# count  500.000000  500.000000
# mean    37.221899   37.689047
# std      5.213119    3.015316
# min     17.074200   29.034000
# 25%     35.030000   36.004525
# 50%     38.022300   37.046250
# 75%     41.000625   40.008775
# max     50.052500   50.004600

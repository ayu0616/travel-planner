# %%
from test import get_scores
import pandas as pd
import os
import numpy as np

# %%
scores_list = []
names = ["sa", "climb_mt", "beam", "define_score"]
for name in names:
    path = os.path.join("../dist/", name)
    scores_list.append(get_scores(path))

# %%
li = np.array(scores_list)
li = li.T
df = pd.DataFrame(li, columns=names)

# %%
df
# Out:
#          sa  climb_mt     beam  define_score
# 0   18.1315   19.0693  16.3056       18.1488
# 1   20.0020   20.0269  16.3752       20.0269
# 2   19.0036   19.0557  14.3483       21.0044
# 3   20.0433   20.0367  17.2231       21.0083
# 4   13.0599   14.0102  13.1058       14.0102
# ..      ...       ...      ...           ...
# 95  19.0096   19.0733  18.2192       20.0428
# 96  20.1315   22.0234  16.3862       20.1254
# 97  19.0150   18.0539  18.0577       19.0150
# 98  23.0345   22.1075  20.2642       23.0345
# 99  18.0146   20.0650  18.1865       21.0559
#
# [100 rows x 4 columns]

# %%
df.plot()
# Out:
# <AxesSubplot: >

# %%
df.sum()
# Out:
# sa              1905.3237
# climb_mt        1963.4424
# beam            1686.5319
# define_score    1979.0615
# dtype: float64

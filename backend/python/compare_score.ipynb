# %%
from test import get_scores
import pandas as pd
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
scores_list = []
names = [
    "sa",
    "climb_mt",
    # "beam",
    # "define_score",
]
for name in names:
    path = os.path.join("../dist/", name)
    scores_list.append(get_scores(path))

# %%
li = np.array(scores_list)
li = li.T
df = pd.DataFrame(li, columns=names)

# %%
df
# Out:
#          sa  climb_mt
# 0   78.0002   77.0004
# 1   93.0001   90.0065
# 2   88.0006   87.0059
# 3   96.0020   94.0011
# 4   87.0009   85.0031
# ..      ...       ...
# 95  85.0025   84.0065
# 96  89.0036   89.0004
# 97  84.0002   84.0107
# 98  90.0106   90.0045
# 99  87.0033   88.0108
#
# [100 rows x 2 columns]

# %%
# 折れ線グラフを描画
df.plot()
plt.xlabel("id")
plt.ylabel("score")
plt.show()

# %%
# ヒストグラムを描画
df.plot.hist(bins=25, alpha=0.5)
plt.xlabel("Score")
plt.show()

# %%
df.plot.box()
plt.ylabel("Score")
plt.show()

# %%
df.sum()
# Out:
# sa          8832.3368
# climb_mt    8776.5987
# dtype: float64
